# %%
import warnings
warnings.filterwarnings("ignore")
from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np

np.random.seed(0)  
train = pd.read_csv('train_dum.csv')
test = pd.read_csv('test_dum.csv')
from sklearn.preprocessing import StandardScaler
X = train.drop(['damage_grade'], axis = 1)
y = train['damage_grade']
y = pd.get_dummies(y)

# %%
from sklearn.ensemble import RandomForestClassifier
import matplotlib.pyplot as plt
rfc = RandomForestClassifier()
rfc.fit(X, y)
# print(rfc.feature_importances_)
plt.figure(figsize=(30, 7))
features = pd.Series(rfc.feature_importances_, index= X.columns)
features.nlargest(50).plot(kind = 'bar', color = 'r')
plt.show()
print(len(X.columns))
print(features.nlargest(50))
features.nlargest(50).index
# Out:
# 68
# geo_level_3_id                            0.152085
# geo_level_1_id                            0.135458
# geo_level_2_id                            0.133641
# age                                       0.124317
# area_percentage                           0.111926
# height_percentage                         0.055980
# count_families                            0.024995
# ground_floor_type_v                       0.017096
# foundation_type_r                         0.015089
# count_floors_pre_eq                       0.014348
# has_superstructure_timber                 0.012228
# has_superstructure_mud_mortar_stone       0.010403
# land_surface_condition_t                  0.009149
# position_s                                0.008422
# land_surface_condition_n                  0.008258
# has_superstructure_cement_mortar_brick    0.007953
# has_superstructure_adobe_mud              0.007815
# position_t                                0.007492
# ...

# %%
# def f1(y_true, y_pred):
#     def recall(y_true, y_pred):
#         """Recall metric.
#         Only computes a batch-wise average of recall.
#         Computes the recall, a metric for multi-label classification of
#         how many relevant items are selected.
#         """
#         true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
#         possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
#         recall = true_positives / (possible_positives + K.epsilon())
#         return recall
 
#     def precision(y_true, y_pred):
#         """Precision metric.
#         Only computes a batch-wise average of precision.
#         Computes the precision, a metric for multi-label classification of
#         how many selected items are relevant.
#         """
#         true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
#         predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
#         precision = true_positives / (predicted_positives + K.epsilon())
#         return precision
#     precision = precision(y_true, y_pred)
#     recall = recall(y_true, y_pred)
#     return 2*((precision*recall)/(precision+recall+K.epsilon()))
# model.compile(loss='binary_crossentropy',
#           optimizer= "adam",
#           metrics=[f1])

# %%
# geo_level_1_id 中位数
geo_level_1_id_1 = list()
geo_level_1_id_2 = list()
geo_level_1_id_3 = list()
for i in range(len(train_values.index)):
    temp_0 = train_values['geo_level_1_id'][i] - 20
    temp_1 = train_values['geo_level_1_id'][i] - 10
    temp_2 = train_values['geo_level_1_id'][i] - 13
    geo_level_1_id_1.append(temp_0)
    geo_level_1_id_2.append(temp_1)
    geo_level_1_id_3.append(temp_2)
    
train_values['geo_level_1_id_1'] = geo_level_1_id_1
train_values['geo_level_1_id_2'] = geo_level_1_id_2
train_values['geo_level_1_id_3'] = geo_level_1_id_3

# geo_level_2_id 中位数
geo_level_2_id_1 = list()
geo_level_2_id_2 = list()
geo_level_2_id_3 = list()
for i in range(len(train_values.index)):
    temp_0 = train_values['geo_level_2_id'][i] - 661
    temp_1 = train_values['geo_level_2_id'][i] - 699
    temp_2 = train_values['geo_level_2_id'][i] - 720
    geo_level_2_id_1.append(temp_0)
    geo_level_2_id_2.append(temp_1)
    geo_level_2_id_3.append(temp_2)
    
train_values['geo_level_2_id_1'] = geo_level_2_id_1
train_values['geo_level_2_id_2'] = geo_level_2_id_2
train_values['geo_level_2_id_3'] = geo_level_2_id_3

# geo_level_3_id 中位数
geo_level_3_id_1 = list()
geo_level_3_id_2 = list()
geo_level_3_id_3 = list()
for i in range(len(train_values.index)):
    temp_0 = train_values['geo_level_3_id'][i] - 6400
    temp_1 = train_values['geo_level_3_id'][i] - 6187
    temp_2 = train_values['geo_level_3_id'][i] - 6362
    geo_level_3_id_1.append(temp_0)
    geo_level_3_id_2.append(temp_1)
    geo_level_3_id_3.append(temp_2)
    
train_values['geo_level_3_id_1'] = geo_level_3_id_1
train_values['geo_level_3_id_2'] = geo_level_3_id_2
train_values['geo_level_3_id_3'] = geo_level_3_id_3

# age 中位数
age_1 = list()
age_2 = list()
age_3 = list()
for i in range(len(train_values.index)):
    temp_0 = train_values['age'][i] - 5
    temp_1 = train_values['age'][i] - 15
    temp_2 = train_values['age'][i] - 20
    age_1.append(temp_0)
    age_2.append(temp_1)
    age_3.append(temp_2)
    
train_values['age_1'] = age_1
train_values['age_2'] = age_2
train_values['age_3'] = age_3

# %%
scaler = StandardScaler()
X = scaler.fit_transform(X)
test_temp = scaler.fit_transform(test)
X_train, X_valid, y_train, y_valid = train_test_split(X, y, test_size = 0.33,random_state = 123)

column_names = train.drop(['damage_grade'], axis = 1)
X_train = pd.DataFrame(X_train, columns = column_names.columns)
X_valid = pd.DataFrame(X_valid, columns = column_names.columns)
test = pd.DataFrame(test_temp, columns = test.columns)

select_list = ['geo_level_1_id', 
                   'geo_level_2_id', 
                   'geo_level_3_id', 
                   'age', 
                   'area_percentage', 
                   'height_percentage', 
                   'count_families', 
                   'foundation_type_r', 
                   'count_floors_pre_eq', 
                   'has_superstructure_mud_mortar_stone',
                   'has_superstructure_timber',
                   'ground_floor_type_v',
                   'land_surface_condition_t',
                   'land_surface_condition_n',
                   'roof_type_n',
                   'other_floor_type_q']

# selected_features = ['geo_level_3_id', 'geo_level_1_id', 'geo_level_2_id', 'age',
#        'area_percentage', 'height_percentage', 'count_families',
#        'ground_floor_type_v', 'count_floors_pre_eq', 'foundation_type_r',
#        'has_superstructure_mud_mortar_stone', 'has_superstructure_timber',
#        'land_surface_condition_t', 'position_s', 'land_surface_condition_n',
#        'has_secondary_use']

input_dim = len(selected_features)
nb_epoch = 100
batch_size = 50


from keras.models import Sequential
from keras.layers.core import Dense, Dropout, Activation

model = Sequential()
model.add(Dense(output_dim=120, input_dim=input_dim, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(output_dim=60, input_dim=120, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(output_dim=3, input_dim=30, activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

model.fit(X_train[selected_features], y_train, nb_epoch=nb_epoch,batch_size=batch_size)
loss,accuracy = model.evaluate(X_valid[selected_features], y_valid)
print('loss:',loss)
print('accuracy:',accuracy)
prediction = model.predict_classes(test[selected_features])

for i in range(len(prediction)):
    prediction[i]+=1

result = pd.DataFrame()

raw_test = pd.read_csv('test.csv')

result['building_id'] = raw_test['building_id']
result['damage_grade'] = prediction
result.to_csv('prediction_result.csv',index = None)
print("预测结果已生成！")
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From c:\users\jomin\appdata\local\programs\python\python37\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From c:\users\jomin\appdata\local\programs\python\python37\lib\site-packages\keras\backend\tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From c:\users\jomin\appdata\local\programs\python\python37\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# ...
