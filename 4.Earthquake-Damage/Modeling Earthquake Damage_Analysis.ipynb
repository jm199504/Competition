# %%
# 分析数据中是否存在异常样本
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")
from pathlib import Path

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler

# %%
train_values = pd.read_csv('train_dum.csv')
train_values.head()
# Out:
#    geo_level_1_id  geo_level_2_id  geo_level_3_id  count_floors_pre_eq  age  \
# 0               6             487           12198                    2   30
# 1               8             900            2812                    2   10
# 2              21             363            8973                    2   10
# 3              22             418           10694                    2   10
# 4              11             131            1488                    3   30
#
#    area_percentage  height_percentage  has_superstructure_adobe_mud  \
# 0                6                  5                             1
# 1                8                  7                             0
# 2                5                  5                             0
# 3                6                  5                             0
# 4                8                  9                             1
#
#    has_superstructure_mud_mortar_stone  has_superstructure_stone_flag  ...  \
# ...

# %%
feature_mean_list = ['geo_level_1_id', 
                   'geo_level_2_id', 
                   'geo_level_3_id', 
                   'age', 
                   'area_percentage', 
                   'height_percentage', 
                   'count_families', 
                   'foundation_type_r', 
                   'count_floors_pre_eq', 
                   'has_superstructure_mud_mortar_stone',
                   'has_superstructure_timber',
                   'ground_floor_type_v',
                   'land_surface_condition_t',
                   'land_surface_condition_n',
                   'roof_type_n',
                   'other_floor_type_q']


for f in feature_mean_list:
#     grouped_df = all_demo.groupby('heart_disease_present')[f].aggregate(np.mean).reset_index()
    grouped_df = train_values.groupby('damage_grade')[f].aggregate(np.median).reset_index()
    print(grouped_df)
    print('\n')
# Out:
#    damage_grade  geo_level_1_id
# 0             1              20
# 1             2              10
# 2             3              13
#
#
#    damage_grade  geo_level_2_id
# 0             1             661
# 1             2             699
# 2             3             720
#
#
#    damage_grade  geo_level_3_id
# 0             1            6400
# 1             2            6187
# 2             3            6362
#
#
#    damage_grade  age
# 0             1    5
# 1             2   15
# 2             3   20
#
#
#    damage_grade  area_percentage
# 0             1                8
# 1             2                7
# 2             3                7
#
#
#    damage_grade  height_percentage
# 0             1                  5
# 1             2                  5
# 2             3                  5
#
#
#    damage_grade  count_families
# 0             1               1
# 1             2               1
# 2             3               1
#
#
#    damage_grade  foundation_type_r
# ...
